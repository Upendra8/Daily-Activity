# %%
import pandas as pd

# %%
series=pd.Series(['BMW','TATA','Mahindra','Toyota'])

# %%
series       #single dimension
# Out:
# 0         BMW
# 1        TATA
# 2    Mahindra
# 3      Toyota
# dtype: object

# %%
colours=pd.Series(["Red","Yellow","Blue","Green"])
colours
car_data=pd.DataFrame({"Factory":series,"Colour":colours})

# %%
car_data
# Out:
#     Factory  Colour
# 0       BMW     Red
# 1      TATA  Yellow
# 2  Mahindra    Blue
# 3    Toyota   Green

# %%
#making this data into spreadhseet or excel sheet
datas=pd.read_csv("ff.csv")

# %%
datas
# Out:
#                 MONDAY   Unnamed: 2  \
# 0    NaN            P1           P2
# 1   ECE1           NaN          DVD
# 2   ECE2            AI          HRD
# 3   ECE3   Artificial            ML
# 4   ECE4  MINI Project           ES
# 5   ECE5  MINIproject            ML
# 6    NaN           NaN          NaN
# 7    NaN           NaN          NaN
# 8    NaN           NaN          NaN
# 9    NaN          S.NO  COURSE CODE
# 10   NaN             1       EC3217
# 11   NaN             2       EC3224
# 12   NaN             3       EC3226
# 13   NaN             4       EC3201
# 14   NaN             5       EC3253
# 15   NaN             6       EC3250
# 16   NaN             7       MA3201
# 17   NaN             8     TE1OE301
# 18   NaN             9     TE1OE502
# 19   NaN            10       HS3202
# 20   NaN            11       EG3283
# 21   NaN            12       MG3201
# 22   NaN            13       MC3201
# 23   NaN            14       EC3215
# 24   NaN            15       EC3254
# ...

# %%
#Exporting a dataframe
datas.to_csv("newone.csv")

# %% [markdown]
# ## Describe data

# %%
datas.dtypes
# Out:
#                object
# MONDAY         object
# Unnamed: 2     object
# Unnamed: 3     object
# Unnamed: 4     object
# Unnamed: 5     object
# Unnamed: 6     object
# Unnamed: 7     object
# TUESDAY        object
# Unnamed: 9     object
# Unnamed: 10    object
# Unnamed: 11    object
# Unnamed: 12    object
# Unnamed: 13    object
# Unnamed: 14    object
# WEDNESDAY      object
# Unnamed: 16    object
# Unnamed: 17    object
# Unnamed: 18    object
# Unnamed: 19    object
# Unnamed: 20    object
# Unnamed: 21    object
# THURSDAY       object
# Unnamed: 23    object
# Unnamed: 24    object
# Unnamed: 25    object
# Unnamed: 26    object
# Unnamed: 27    object
# Unnamed: 28    object
# Friday         object
# Unnamed: 30    object
# Unnamed: 31    object
# Unnamed: 32    object
# Unnamed: 33    object
# Unnamed: 34    object
# Unnamed: 35    object
# Saturday       object
# Unnamed: 37    object
# Unnamed: 38    object
# Unnamed: 39    object
# Unnamed: 40    object
# ...

# %%
datas.columns
# Out:
# Index([' ', 'MONDAY', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5',
#        'Unnamed: 6', 'Unnamed: 7', 'TUESDAY', 'Unnamed: 9', 'Unnamed: 10',
#        'Unnamed: 11', 'Unnamed: 12', 'Unnamed: 13', 'Unnamed: 14', 'WEDNESDAY',
#        'Unnamed: 16', 'Unnamed: 17', 'Unnamed: 18', 'Unnamed: 19',
#        'Unnamed: 20', 'Unnamed: 21', 'THURSDAY', 'Unnamed: 23', 'Unnamed: 24',
#        'Unnamed: 25', 'Unnamed: 26', 'Unnamed: 27', 'Unnamed: 28', 'Friday',
#        'Unnamed: 30', 'Unnamed: 31', 'Unnamed: 32', 'Unnamed: 33',
#        'Unnamed: 34', 'Unnamed: 35', 'Saturday', 'Unnamed: 37', 'Unnamed: 38',
#        'Unnamed: 39', 'Unnamed: 40', 'Unnamed: 41', 'Unnamed: 42'],
#       dtype='object')

# %%
 datas.index
# Out:
# RangeIndex(start=0, stop=33, step=1)

# %%
datas.describe()
# Out:
#              MONDAY Unnamed: 2                Unnamed: 3 Unnamed: 4  \
# count      5     21         22                        20          4
# unique     5     21         21                        20          4
# top     ECE1      6         ML  Digital Image Processing        DVD
# freq       1      1          2                         1          1
#
#        Unnamed: 5                           Unnamed: 6  Unnamed: 7 TUESDAY  \
# count           2                                   10           2       6
# unique          2                                   10           2       4
# top            P5  DIP-ECE3,ECE4,ECE5 Assemble in ECE3  TELUGU /MA      ML
# freq            1                                    1           1       3
#
#        Unnamed: 9  ... Unnamed: 33  Unnamed: 34 Unnamed: 35   Saturday  \
# count           4  ...           4            4           4          2
# unique          4  ...           4            4           4          2
# ...

# %% [markdown]
#   ## viewing and Selecting data

# %%
datas.head(2)
# Out:
#         MONDAY Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6  \
# 0   NaN     P1         P2         P3         P4         P5         P6
# 1  ECE1    NaN        DVD        DIP         ES        ADC  Telugu/MA
#
#    Unnamed: 7 TUESDAY Unnamed: 9  ... Unnamed: 33 Unnamed: 34 Unnamed: 35  \
# 0          P7      P1         P2  ...          P5          P6          P7
# 1  TELUGU /MA      ML        DVD  ...    Robotics         NaN         NaN
#
#     Saturday Unnamed: 37 Unnamed: 38 Unnamed: 39  Unnamed: 40 Unnamed: 41  \
# 0         P1          P2          P3          P4           P5          P6
# 1  Telugu/MA          AI         HRD         CDC  MINIproject         NaN
#
#   Unnamed: 42
# 0          P7
# 1         NaN
#
# [2 rows x 43 columns]

# %%
#.loc and .iloc

animals=pd.Series(["Cat","Dog","Bird","Snakes"],index=[3,9,8,3])

# %%
animals.loc[9]
# Out:
# 'Dog'

# %%
animals
# Out:
# 3       Cat
# 9       Dog
# 8      Bird
# 3    Snakes
# dtype: object
